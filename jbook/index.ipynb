# %% [markdown]
# # Narrative Science
#
# ## Abstract
#
# Narrative science is a concept of writing a piece that provides scientific and technical details in a research project with a narrative (i.e., context-based) structure so that readers can digest all the information in the text without cross-referencing.
#
# ## Introduction
#
# bla bla...
#
# ```{note}
# Hey where's the content?
# ```
#
# ### Task 1
#
# ### Task 2
#
# ### Task 3

# %% [markdown]
# | Week # | Topic               | Hands-on    |
# |--------|---------------------|-------------|
# | 1      | Course introduction | Hands-on 1  |
# | 2      | Lecture 1           | Hands-on 1  |

# %% [markdown]
# ```{list-table}
# :header-rows: 1
#
# * - Week #
#   - Topic
#   - Hands-on
# * - 1
#   - Course introduction
#   - Hands-on 1
# * - 2
#   - Lecthand1-
#   -
# ```s-on 1
# ```

# %% [markdown]
# ## Task 2
#
# ```{figure} https://whyjz.github.io/ncu-open-science/_images/csrsr_logo.png
# :name: fig-csrsr
# :align: center
#
# The Logo of CSRSR.
# ```
#
# This statement says that {numref}`fig-csrsr` is the logo f CSRSR.
# o。

# %% [markdown]
# Glaciers in the High Mountain Asia can speed up in the summer and slow down in the winter [@Baldacchino2025].

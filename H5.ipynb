# %%
# !pip install rioxarray hvplot
# Out:
# WARNING: Skipping /opt/conda/lib/python3.11/site-packages/nlopt-2.7.1.dist-info due to invalid metadata entry 'name'
# Collecting rioxarray
#   Using cached rioxarray-0.19.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting hvplot
#   Using cached hvplot-0.12.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from rioxarray) (23.2)
# Collecting rasterio>=1.4.3 (from rioxarray)
#   Using cached rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting xarray>=2024.7.0 (from rioxarray)
#   Downloading xarray-2025.11.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pyproj>=3.3 in /opt/conda/lib/python3.11/site-packages (from rioxarray) (3.5.0)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.11/site-packages (from rioxarray) (1.26.2)
# Requirement already satisfied: bokeh>=3.1 in /opt/conda/lib/python3.11/site-packages (from hvplot) (3.3.2)
# Collecting colorcet>=2 (from hvplot)
#   Using cached colorcet-3.1.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting holoviews>=1.19.0 (from hvplot)
#   Using cached holoviews-1.22.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas>=1.3 in /opt/conda/lib/python3.11/site-packages (from hvplot) (2.1.4)
# Collecting panel>=1.0 (from hvplot)
#   Using cached panel-1.8.3-py3-none-any.whl.metadata (15 kB)
# Collecting param<3.0,>=1.12.0 (from hvplot)
#   Using cached param-2.3.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: Jinja2>=2.9 in /opt/conda/lib/python3.11/site-packages (from bokeh>=3.1->hvplot) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /opt/conda/lib/python3.11/site-packages (from bokeh>=3.1->hvplot) (1.2.0)
# Requirement already satisfied: pillow>=7.1.0 in /opt/conda/lib/python3.11/site-packages (from bokeh>=3.1->hvplot) (10.0.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/conda/lib/python3.11/site-packages (from bokeh>=3.1->hvplot) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /opt/conda/lib/python3.11/site-packages (from bokeh>=3.1->hvplot) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /opt/conda/lib/python3.11/site-packages (from bokeh>=3.1->hvplot) (2023.10.1)
# Collecting narwhals>=2 (from holoviews>=1.19.0->hvplot)
#   Using cached narwhals-2.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from holoviews>=1.19.0->hvplot) (2.8.2)
# Collecting pyviz-comms>=2.1 (from holoviews>=1.19.0->hvplot)
#   Using cached pyviz_comms-3.0.6-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3->hvplot) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3->hvplot) (2023.3)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.11/site-packages (from panel>=1.0->hvplot) (6.1.0)
# Collecting bokeh>=3.1 (from hvplot)
#   Using cached bokeh-3.8.1-py3-none-any.whl.metadata (10 kB)
# Collecting linkify-it-py (from panel>=1.0->hvplot)
#   Using cached linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: markdown in /opt/conda/lib/python3.11/site-packages (from panel>=1.0->hvplot) (3.5.1)
# Requirement already satisfied: markdown-it-py in /opt/conda/lib/python3.11/site-packages (from panel>=1.0->hvplot) (3.0.0)
# Collecting mdit-py-plugins (from panel>=1.0->hvplot)
#   Using cached mdit_py_plugins-0.5.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from panel>=1.0->hvplot) (2.28.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from panel>=1.0->hvplot) (4.66.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from panel>=1.0->hvplot) (4.9.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from pyproj>=3.3->rioxarray) (2023.11.17)
# Requirement already satisfied: affine in /opt/conda/lib/python3.11/site-packages (from rasterio>=1.4.3->rioxarray) (2.4.0)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.11/site-packages (from rasterio>=1.4.3->rioxarray) (23.1.0)
# Requirement already satisfied: click>=4.0 in /opt/conda/lib/python3.11/site-packages (from rasterio>=1.4.3->rioxarray) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.11/site-packages (from rasterio>=1.4.3->rioxarray) (0.7.2)
# Requirement already satisfied: click-plugins in /opt/conda/lib/python3.11/site-packages (from rasterio>=1.4.3->rioxarray) (1.1.1)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.11/site-packages (from rasterio>=1.4.3->rioxarray) (3.1.1)
# Collecting packaging (from rioxarray)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pandas>=1.3 (from hvplot)
#   Using cached pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh>=3.1->hvplot) (2.1.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->holoviews>=1.19.0->hvplot) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.11/site-packages (from bleach->panel>=1.0->hvplot) (0.5.1)
# Collecting uc-micro-py (from linkify-it-py->panel>=1.0->hvplot)
#   Using cached uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py->panel>=1.0->hvplot) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->panel>=1.0->hvplot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->panel>=1.0->hvplot) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->panel>=1.0->hvplot) (1.26.18)
# Using cached rioxarray-0.19.0-py3-none-any.whl (62 kB)
# Using cached hvplot-0.12.1-py3-none-any.whl (175 kB)
# Using cached colorcet-3.1.0-py3-none-any.whl (260 kB)
# Using cached holoviews-1.22.0-py3-none-any.whl (5.9 MB)
# Using cached panel-1.8.3-py3-none-any.whl (30.2 MB)
# Using cached bokeh-3.8.1-py3-none-any.whl (7.2 MB)
# Using cached param-2.3.0-py3-none-any.whl (139 kB)
# Using cached rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
# Downloading xarray-2025.11.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.8 MB/s eta 0:00:00:00:010:01
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
# Using cached narwhals-2.12.0-py3-none-any.whl (425 kB)
# Using cached pyviz_comms-3.0.6-py3-none-any.whl (84 kB)
# Using cached linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Using cached mdit_py_plugins-0.5.0-py3-none-any.whl (57 kB)
# Using cached uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# WARNING: Skipping /opt/conda/lib/python3.11/site-packages/nlopt-2.7.1.dist-info due to invalid metadata entry 'name'
# Installing collected packages: uc-micro-py, param, packaging, narwhals, colorcet, rasterio, pyviz-comms, pandas, mdit-py-plugins, linkify-it-py, xarray, bokeh, rioxarray, panel, holoviews, hvplot
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: rasterio
#     WARNING: Skipping /opt/conda/lib/python3.11/site-packages/nlopt-2.7.1.dist-info due to invalid metadata entry 'name'
#     Found existing installation: rasterio 1.3.7
#     Uninstalling rasterio-1.3.7:
#       Successfully uninstalled rasterio-1.3.7
#   Attempting uninstall: pandas
#     WARNING: Skipping /opt/conda/lib/python3.11/site-packages/nlopt-2.7.1.dist-info due to invalid metadata entry 'name'
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 3.3.2
#     Uninstalling bokeh-3.3.2:
#       Successfully uninstalled bokeh-3.3.2
# Successfully installed bokeh-3.8.1 colorcet-3.1.0 holoviews-1.22.0 hvplot-0.12.1 linkify-it-py-2.0.3 mdit-py-plugins-0.5.0 narwhals-2.12.0 packaging-25.0 pandas-2.3.3 panel-1.8.3 param-2.3.0 pyviz-comms-3.0.6 rasterio-1.4.3 rioxarray-0.19.0 uc-micro-py-1.0.3 xarray-2025.11.0

# %%
import rioxarray
import hvplot.xarray
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e9e9dcf7-1dc0-4253-9436-a415d722dbbe'>
#   <div id="d52e83d2-ae39-40a4-af91-d66c1f5b1d8b" data-root-id="e9e9dcf7-1dc0-4253-9436-a415d722dbbe" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"ec6b883b-cdf1-4af9-9afb-476e9b6bc4bb":{"version":"3.8.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"cbbd16a4-8afb-436d-aca4-7a6fb0559b52","attributes":{"notifications":{"type":"object","name":"Notifications","id":"f4ee3596-e10a-4954-b51c-688d7942960e"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"e9e9dcf7-1dc0-4253-9436-a415d722dbbe"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"99645e24-b846-46d0-aa7c-80a59777bb01","attributes":{"plot_id":"e9e9dcf7-1dc0-4253-9436-a415d722dbbe","comm_id":"1fb2abd3a31d45419ebaaf3c93d78850","client_comm_id":"4577b6b86743427db0b5ea0ab1139416"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"ec6b883b-cdf1-4af9-9afb-476e9b6bc4bb","roots":{"e9e9dcf7-1dc0-4253-9436-a415d722dbbe":"d52e83d2-ae39-40a4-af91-d66c1f5b1d8b"},"root_ids":["e9e9dcf7-1dc0-4253-9436-a415d722dbbe"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
image_url = 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/51/R/UH/2023/3/S2B_51RUH_20230311_0_L2A/TCI.tif'
img = rioxarray.open_rasterio(image_url)
#img.hvplot.image()

# %%
# da stands for data array
da = rioxarray.open_rasterio(image_url)
# Entering the object name only will print a quick overview of the data set
da
# Out:
# <xarray.DataArray (band: 3, y: 10980, x: 10980)> Size: 362MB
# [361681200 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 24B 1 2 3
#   * y            (y) float64 88kB 2.8e+06 2.8e+06 2.8e+06 ... 2.69e+06 2.69e+06
#   * x            (x) float64 88kB 3e+05 3e+05 3e+05 ... 4.098e+05 4.098e+05
#     spatial_ref  int64 8B 0
# Attributes:
#     OVR_RESAMPLING_ALG:  AVERAGE
#     AREA_OR_POINT:       Area
#     _FillValue:          0
#     scale_factor:        1.0
#     add_offset:          0.0

# %%
print(f"Grid width: {da.rio.width} pixels")
print(f"Grid height: {da.rio.height} pixels")
print(f"Geospatial transformation (m): \n{da.rio.transform()}")
# Out:
# Grid width: 10980 pixels
# Grid height: 10980 pixels
# Geospatial transformation (m):
# | 10.00, 0.00, 300000.00|
# | 0.00,-10.00, 2800020.00|
# | 0.00, 0.00, 1.00|
